# %%
import datasource
import pandas as pd

lastest_data = datasource.lastest_datetime_data()
lastest_df = pd.DataFrame(lastest_data, columns=['站點名稱','更新時間','行政區','地址','總數','可借', '可還'])
lastest_df
# Out:
#                          站點名稱                 更新時間  行政區                   地址  \
# 0           YouBike2.0_致伸科技大樓  2023-11-16 11:19:14  內湖區             瑞光路669號旁
# 1       YouBike2.0_內湖路一段288巷口  2023-11-16 11:19:14  內湖區           內湖路一段290號前
# 2         YouBike2.0_大都會客運內湖站  2023-11-16 11:19:14  內湖區       民權東路六段11巷25號對側
# 3             YouBike2.0_瑞湖公園  2023-11-16 11:19:14  內湖區  民權東路六段15巷/民權東路六段19巷
# 4           YouBike2.0_台灣世曦大樓  2023-11-16 11:19:14  內湖區              陽光街323號
# ...                       ...                  ...  ...                  ...
# 1318          YouBike2.0_臺北花市  2023-11-29 14:59:15  內湖區          新湖三路28號前人行道
# 1319        YouBike2.0_行善社會住宅  2023-11-29 14:59:15  內湖區         行愛路與新湖一路口西南側
# 1320  YouBike2.0_康寧路三段99巷17弄口  2023-11-29 14:59:15  內湖區        康寧路三段99巷19號對側
# 1321   YouBike2.0_堤頂大道二段407巷口  2023-11-29 14:59:15  內湖區          堤頂大道二段405號前
# 1322       YouBike2.0_海德堡科技大樓  2023-11-29 14:59:15  內湖區          堤頂大道二段473號前
#
#       總數  可借  可還
# 0     17   9   8
# 1     20   0  20
# 2     15   5  10
# 3     15   6   9
# 4     16  13   2
# ...   ..  ..  ..
# 1318  20   8  12
# 1319  23   0  23
# 1320  15  13   2
# 1321  15   6   9
# 1322  12   2  10
#
# [1323 rows x 7 columns]

# %%
lastest_df1 = lastest_df.reset_index()
lastest_df1['站點名稱'] = lastest_df1['站點名稱'].map(lambda name:name[11:])  #從第11開始  #只能執行一次

# %%
lastest_df1
# Out:
#       index          站點名稱                 更新時間  行政區                   地址  總數  \
# 0         0        致伸科技大樓  2023-11-16 11:19:14  內湖區             瑞光路669號旁  17
# 1         1    內湖路一段288巷口  2023-11-16 11:19:14  內湖區           內湖路一段290號前  20
# 2         2      大都會客運內湖站  2023-11-16 11:19:14  內湖區       民權東路六段11巷25號對側  15
# 3         3          瑞湖公園  2023-11-16 11:19:14  內湖區  民權東路六段15巷/民權東路六段19巷  15
# 4         4        台灣世曦大樓  2023-11-16 11:19:14  內湖區              陽光街323號  16
# ...     ...           ...                  ...  ...                  ...  ..
# 1318   1318          臺北花市  2023-11-29 14:59:15  內湖區          新湖三路28號前人行道  20
# 1319   1319        行善社會住宅  2023-11-29 14:59:15  內湖區         行愛路與新湖一路口西南側  23
# 1320   1320  康寧路三段99巷17弄口  2023-11-29 14:59:15  內湖區        康寧路三段99巷19號對側  15
# 1321   1321   堤頂大道二段407巷口  2023-11-29 14:59:15  內湖區          堤頂大道二段405號前  15
# 1322   1322       海德堡科技大樓  2023-11-29 14:59:15  內湖區          堤頂大道二段473號前  12
#
#       可借  可還
# 0      9   8
# 1      0  20
# 2      5  10
# 3      6   9
# 4     13   2
# ...   ..  ..
# 1318   8  12
# 1319   0  23
# 1320  13   2
# 1321   6   9
# 1322   2  10
#
# [1323 rows x 8 columns]
